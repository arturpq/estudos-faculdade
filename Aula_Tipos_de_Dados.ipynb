# %% [markdown]
# <a href="https://colab.research.google.com/github/arturpq/estudos-faculdade/blob/main/Aula_Tipos_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print

# %%
print('primeiro note')
# Out:
# primeiro note

# %% [markdown]
# Tipos de Variável e Operadores

# %%
#variavel
nome = 'qualquer'
#print
print(nome)
no1 = 11.2
no2 = 10.3
verifica = no1 == no2
print(verifica)
soma = no1 + no2
print(soma)
type(soma)
# Out:
# qualquer
# False
# 21.5
# float

# %% [markdown]
# Check de Tipos

# %%
a = 100
b = 25.6
c = a > b
d = 'Chimpanze'
tipoa = type(a)
tipob = type(b)
tipoc = type(c)
tipod = type(d)
tipo = [type(a), type(b), type(c), type(d)]
print(tipo[0], tipo[1], tipo[2], tipo[3])
# Out:
# <class 'int'> <class 'float'> <class 'bool'> <class 'str'>

# %% [markdown]
# If Else

# %%
notaAprovado = 7.0
notaWalison = 7.0
notaReprovado = 4
if(notaAprovado <= notaWalison):
  print('aprovado')
elif (notaWalison <= notaReprovado):
  print('reprovado')
else: print('recuperação')
# Out:
# aprovado

# %% [markdown]
# While e List

# %%
varBool = [100 < 200, 85 == 6, 'pablo' == 'pablo', 25 == '25', 30==(6*5), 'Flamengo' == 'Vasco']
checkBool = 0
print(len(varBool))
while(checkBool != len(varBool)): 
  print(varBool[checkBool])
  checkBool = checkBool + 1
# Out:
# 6
# True
# False
# True
# False
# True
# False

# %% [markdown]
# Teste Else If

# %%
notaWalison = 7 
if(notaWalison <= 4):
  print('reprovado')
elif(notaWalison <= 7):
  print('recuperação')
else:
 print('aprovado')
# Out:
# recuperação

# %% [markdown]
# Input Dados

# %%
#Vem como String
nota1 = input('Nota')
nota2 = input('Nota2')
print(nota1 + nota2)
# Out:
# Nota1
# Nota22
# 12

# %%
#Parse
nota1 = float(input('Nota'))
nota2 = float(input('Nota2'))
print((nota1 + nota2)/2)
# Out:
# Nota1
# Nota26
# 4.0

# %%
nota = [float(input('Nota')), float(input('Nota2')), float(input('Nota3'))]

print ((nota[0]+nota[1]+nota[2])/3)
# Out:
# Nota7
# Nota24
# Nota33
# 4.666666666666667

# %% [markdown]
# Teste de Lista

# %%
numNotas = int(input('Quantas notas você tem?'))
notaCheck = 0
notas = [float(input('Nota'))]
while (numNotas != len(notas)):

notas.insert()

print ((nota[0]+nota[1]+nota[2])/3)
# Out:
#   File "<ipython-input-86-9f3b7fc76890>", line 4
#     nota[] = [float(input('Nota'))]
#     ^
# IndentationError: expected an indented block
